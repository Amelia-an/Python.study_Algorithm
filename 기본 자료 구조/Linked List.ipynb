# %% [markdown]
# # 링크드 리스트(Linked List)
#
# 1. 데이터를 순서대로 저장해준다
# 2. 요소를 계속 추가할 수 있다.
#
# '노드(node)'라는 데이터를 저장하고 각 노드들을 순서대로 연결시켜서 만든 자료 구조
# * 노드(node) -> data, next 2가지 속성이 존재
#
# ex. n_1.next = n_2 ####### n_1이라는 node 다음에 n_2 node를 불러오다

# %%
class Node:
    """링크드 리스트의 노드 클래스"""
    def __init__(self, data):
        self.data = data # 노드가 저장하는 데이터
        self.next = None # 다음 노드에 대한 레퍼런스
        
# 데이터 2, 3, 5, 7, 11 을 담는 노드들 생성
head_node = Node(2)
node_1 = Node(3)
node_2 = Node(5)
node_3 = Node(7)
tail_node = Node(11)

# 노드 연결
head_node.next = node_1
node_1.next = node_2
node_2.next = node_3
node_3.next = tail_node

# 노드 순서대로 출력
iterator = head_node # iterator 반복문으로 리스트 돌 때 도움을 주는 함수

while iterator is not None:
    print(iterator.data)
    iterator = iterator.next
# Out:
# 2
# 3
# 5
# 7
# 11

# %%
class Node:
    #"""링크드 리스트의 노드 클래스"""
    def __init__(self, data):
        self.data = data # 노드가 저장하는 데이터
        self.next = None # 다음 노드에 대한 레퍼런스

class LinkedList:
    #"""링크드 리스트 클래스"""

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, data):
        #"""링크드 리스트 추가 연산 메소드"""
        new_node = Node(data)
        
        if self.head is None: # 링크드 리스트가 비어 있는 경우
            self.head = new_node
            self.tail = new_node
        else:                 # 링크드 리스트가 비어 있지 않은 경우
            self.tail.next = new_node
            self.tail = new_node

#"""링크드 리스트를 문자열로 표현해서 리턴하는 메소드"""
    def __str__(self):
        res_str = "ㅣ"
# 링크드 리스트 안에 모든 노드를 돌기 위한 변수, 일단 가장 앞노드로 정의
        iterator = self.head

# 링크드 리스트 끝까지 돔
        while iterator is not None:
    # 각 노드의 데이터를 리턴하는 문자열에 더해줌
            res_str += f" {iterator.data} ㅣ"
            iterator = iterator.next # 다음 노드로 넘어감

        return res_str

# 새로운 링크드 리스트 생성
Linked_List = LinkedList()

# 링크드 리스트에 데이터 추가
Linked_List.append(2)
Linked_List.append(3)
Linked_List.append(5)
Linked_List.append(7)
Linked_List.append(11)

print(Linked_List)

# 링크드 리스트 출력
#iterator = my_list.head

# while iterator is not None:
    #print(iterator.data)
    #iterator = iterator.next
# Out:
# ㅣ 2 ㅣ 3 ㅣ 5 ㅣ 7 ㅣ 11 ㅣ

# %%
class Node:
    #"""링크드 리스트의 노드 클래스"""
    def __init__(self, data):
        self.data = data # 노드가 저장하는 데이터
        self.next = None # 다음 노드에 대한 레퍼런스

class LinkedList:
    #"""링크드 리스트 클래스"""

    def __init__(self):
        self.head = None
        self.tail = None

    def find(self, index): # 링크드 리스트 접근 연산 메소드, 파라티머 인덱스는 항상 있다고 가정
        iterator = self.head

        for _ in range(index):
            iterator = iterator.next

        return iterator
        
    def append(self, data):
        #"""링크드 리스트 추가 연산 메소드"""
        new_node = Node(data)
        
        if self.head is None: # 링크드 리스트가 비어 있는 경우
            self.head = new_node
            self.tail = new_node
        else:                 # 링크드 리스트가 비어 있지 않은 경우
            self.tail.next = new_node
            self.tail = new_node

#"""링크드 리스트를 문자열로 표현해서 리턴하는 메소드"""
    def __str__(self):
        res_str = "ㅣ"
# 링크드 리스트 안에 모든 노드를 돌기 위한 변수, 일단 가장 앞노드로 정의
        iterator = self.head

# 링크드 리스트 끝까지 돔
        while iterator is not None:
    # 각 노드의 데이터를 리턴하는 문자열에 더해줌
            res_str += "{} ㅣ".format(iterator.data)# = f" {iterator.data} ㅣ"
            iterator = iterator.next # 다음 노드로 넘어감

        return res_str

# 새로운 링크드 리스트 생성
Linked_List = LinkedList()

# 링크드 리스트에 데이터 추가
Linked_List.append(2)
Linked_List.append(3)
Linked_List.append(5)
Linked_List.append(7)
Linked_List.append(11)


# 링크드 리스트 노드에 접근(데이터 가져오기)
print(Linked_List.find(3).data)

# 링크드 리스트 노드에 접근(데이터 바꾸기)
Linked_List.find(2).data = 13

print(Linked_List)
# Out:
# 7
# ㅣ2 ㅣ3 ㅣ13 ㅣ7 ㅣ11 ㅣ

# %%
class Node:
    #"""링크드 리스트의 노드 클래스"""
    def __init__(self, data):
        self.data = data # 노드가 저장하는 데이터
        self.next = None # 다음 노드에 대한 레퍼런스

class Linked_List:
    #"""링크드 리스트 클래스"""

    def __init__(self):
        self.head = None
        self.tail = None


    def find_node_with_data(self, data):
    #"""링크드 리스트에서 탐색 연산 메소드. 단, 해당 노드가 없으면 None을 리턴한다"""
        iterator = self.head  # 링크드 리스트를 돌기 위해 필요한 노드 변수

    # 링크드 리스트 전체를 돈다
        while iterator is not None:
        # iterator 노드의 데이터가 찾는 데이터면 iterator를 리턴한다
            if iterator.data == data:
                return iterator
            iterator = iterator.next  # 다음 노드로 넘어간다

    # 링크드 리스트 안에 원하는 데이터가 없었기 때문에 None 리턴한다
        return None 
    def append(self, data):
        #"""링크드 리스트 추가 연산 메소드"""
            new_node = Node(data)
        
            if self.head is None: # 링크드 리스트가 비어 있는 경우
                self.head = new_node
                self.tail = new_node
            else:                 # 링크드 리스트가 비어 있지 않은 경우
                self.tail.next = new_node
                self.tail = new_node

# 새로운 링크드 리스트 생성
Linked_List = LinkedList()

# 링크드 리스트에 데이터 추가
Linked_List.append(2)
Linked_List.append(3)
Linked_List.append(5)
Linked_List.append(7)
Linked_List.append(11)


# 데이터 탐색
node_with_3 = Linked_List.find_node_with_data(3)

if not node_with_3 is None:
    print(node_with_3.data)
else:
    print("3을 갖는 노드는 없다 시키야")

node_with_5 = Linked_List.find_node_with_data(5)

if not node_with_5 is None:
    print(node_with_5.data)
else:
    print("없다")

node_with_10 = Linked_List.find_node_with_data(10)

if not node_with_10 is None:
    print(node_with_10.data)
else:
    print("없다고")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9204\3244738871.py in <module>
#      49
#      50 # 데이터 탐색
# ---> 51 node_with_3 = Linked_List.find_node_with_data(3)
#      52
#      53 if not node_with_3 is None:
#
# AttributeError: 'LinkedList' object has no attribute 'find_node_with_data'
